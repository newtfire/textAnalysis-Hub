# %% [markdown]
# ## Words to Network Data
#
# Now that we know some ways to pull an interesting selection of words, let's think about them like a network. Network analysis involves looking at how things relate to each other based on shared properties.
#
# In this notebook, we will address a simple research question: Which **files** (or **chapters**, or **scenes**, or **authors**, or **titles**) share each others' top 5 or 10 **verbs** (or **adjectives**, or **nouns**, or **WordNet synsets**, etc)?
#
# We will try exploring this as a network of data and import it into network visualization software.
#
# ### Installs in your Terminal
# * If you did not do this in the previous notebook: `pip install spacy` (or `python3.12 -m pip install spacy`)
# * We need the **pandas** library to make dataframes: `pip install pandas` (or `python3.12 -m pip install pandas`)
#
# <pre>
#     ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣤⣶⣿⣷⣦⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
# ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢸⣿⣿⣿⣿⣿⡇⠀⠀⠀⠀⠀⠀⠀⣰⣿⣿⣿⣦⡀
# ⠀⠀⠀⠀⢀⠄⠀⠀⠀⠀⢈⣿⣿⣿⠟⠛⠁⠀⠀⠀⠀⠀⠀⠐⢿⣿⣿⣿⣿⣷
# ⠀⠀⢀⡔⠁⠀⠀⠀⢀⣴⡿⠃⠈⠁⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⢿⣿⠟⠁
# ⠀⣠⡟⠀⠀⠀⠀⣰⣿⣿⠁⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
# ⢠⣿⠁⠀⠀⠀⢰⣿⣿⡏⠀⠀⠀⢀⣤⣤⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
# ⣾⣿⠀⠀⠀⠀⢸⣿⣿⡇⠀⠀⢠⣿⣿⣿⣿⠀⠀⠀⠀⣰⣾⣶⣆⠀⠀⠀⠀⡄
# ⣿⣿⡀⠀⠀⠀⢸⣿⣿⣧⠀⠀⢸⣿⣿⡿⠃⠀⠀⠀⠀⢿⣿⣿⣿⡆⠀⠀⢸⣧
# ⢿⣿⣧⠀⠀⠀⢸⣿⣿⣿⣦⡀⠀⠉⠉⠀⠀⠀⠀⠀⠀⠈⠻⣿⠿⠁⠀⢠⣿⣿
# ⢸⣿⣿⣷⣄⠀⣿⣿⣿⣿⣿⣿⣷⣦⣄⠀⠲⣶⣶⣶⠀⠀⠀⠀⠀⣀⣴⣿⣿⣿
# ⢰⣿⣿⣿⣿⣷⣽⣿⣿⣿⣿⣿⣿⣿⣿⣦⡄⣬⣅⣀⣠⣾⣿⣿⣿⣿⣿⣿⣿⡟
# ⠈⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣷⣤⣤⣾⣿⣿⣿⣿⣿⣿⣿⣿⣿⠇
# ⠀⠹⣿⣿⣿⣿⣿⣿⢿⣿⣿⣿⣿⣿⣿⣿⣿⣿⡏⠀⠈⣿⣿⣿⣿⣿⣿⣿⡿⠀
# ⠀⠀⠻⣿⣿⣿⣿⣿⡎⢿⣿⣿⣿⣿⣿⣿⣿⣿⡇⠀⠀⣿⣿⣿⣿⣿⣿⣿⠃⠀
# ⠀⠀⠀⠙⠻⠿⣿⣿⠗⠀⢻⣿⣿⣿⣿⣿⣿⣿⡇⠀⢸⣿⣿⣿⣿⣿⡿⠃⠀⠀
# ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠹⣿⣿⣿⣿⣿⣿⣿⠀⢸⣿⣿⣿⡿⠟⠁⠀⠀⠀
# ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⠛⠿⢿⣿⣿⡿⠇⠀⠈⠉⠁⠀⠀⠀⠀⠀⠀
# </pre>
#
#
#
# Image credit: <https://emojicombos.com/panda-ascii-art>
#
# ### Language Models
# Like NLTK's collections that we downloaded, [spaCy has trained language models](https://spacy.io/usage/models) to download. You download these in your Python script after you import spacy, and after you download once, you don't need to do it again (so you can comment out the download line). We're going to try the medium and large models in English. (It's good to know that both spaCy and NLTK have resources for NLP on other languages, too!)

# %%
import spacy
import os

# %% [markdown]
# ### Downloading language models
# To work with spaCy's pre-trained language models, you need to download them to you virtual environment. There are:
# * en_core_web_sm (smallest--not as much info as the others)
# * **en_core_web_md** (Pretty good date here, size: 34 MB )
# * **en_core_web_lg** (Lots of data here, size: 400 MB.)
# Note that the LARGEST  one will have the most data and probably be the most reliable.

# %%
# CAN YOU SKIP THIS???
# After you download a model into your virtual environment for the first time, you can comment out the download line.
# spaCy's medium and large models will give us the best results for NLP tagging.
# nlp = spacy.cli.download("en_core_web_sm")
# nlp = spacy.cli.download("en_core_web_md")
nlp = spacy.cli.download("en_core_web_lg")

# %% [markdown]
# ### Load the model
# Now we redefine the nlp variable to LOAD the model you downloaded.

# %%
nlp = spacy.load("en_core_web_lg")

# %% [markdown]
# ## File Collection
# You can set this to read a collection of text files that you've prepped for natural language processing.
# For this notebook, we'll work with just the dialogue text we pulled from the One Piece project.
# The text is organized as one file for each volume of OnePiece, so we can maybe explore how much the dialogue is relying on certain words, and how it might be changing over the volumes.
#
# We're going to get volume information from OnePiece's filenames (which look like this: `vol-9.txt'. We can use the `os` library to help us isolate the filename from the file extension. Let's try that so we can simplify our references to the volumes when we output our data.

# %%
collPath = 'onepiece-nlp-text'
for file in os.listdir(collPath):
    if file.endswith(".txt"):
        filepath = f"{collPath}/{file}"
        name, extension = os.path.splitext(file)
        print(name)
        with open(filepath, 'r', encoding='utf8') as f:
            readFile = f.read()
            lengthFile = len(readFile)
            print(lengthFile)
# We're just printing out the filepaths and lengths of the files as a "smoke test" to see if we're reading the files.

# %% [markdown]
# ## Collect some words with a little help from spaCy
# Let's build this up to go file by file. We'll start by surveying what we have...(Ultimately we want to collect the top 5 or 10 most frequently repeating words of a kind.)

# %%
# SURVEY IT ALL! :-) (Yeah, lots of data...)
for file in os.listdir(collPath):
    if file.endswith(".txt"):
        filepath = f"{collPath}/{file}"
        name, extension = os.path.splitext(file)
        print(name)
        with open(filepath, 'r', encoding='utf8') as f:
            readFile = f.read()
            spacyRead = nlp(readFile)
            for token in spacyRead:
                print(token.text, "---->", token.pos_, ":::::", token.lemma_)

# %%
# Remember, we can request an explanation from spaCy of its tags: 
spacy.explain("DET")
# Out:
# 'determiner'

# %% [markdown]
# ### Okay, let's select something interesting
#  ...and maybe only collect the lemmas.
#
# Let's do this with a **function** call. We can easily switch the kind of word we want to output this way.
# Here we are starting to associate words wtih volumes...we're going to refine that by making a dataframe next.

# %%
def wordCollector(words, unit):
    wordList = []
    for token in words:
        if token.pos_ == "ADJ":
            wordList.append((token.lemma_, unit))
    uniqueLems = set(wordList)
    return uniqueLems

for file in os.listdir(collPath):
    if file.endswith(".txt"):
        filepath = f"{collPath}/{file}"
        name, extension = os.path.splitext(file)
        with open(filepath, 'r', encoding='utf8') as f:
            readFile = f.read()
            spacyRead = nlp(readFile)
            myWords = wordCollector(spacyRead, name)
            print(myWords)
# Out:
# {('sorry', 'vol-9'), ('young', 'vol-9'), ('dry', 'vol-9'), ('pivoting', 'vol-9'), ('bad', 'vol-9'), ('small', 'vol-9'), ('naughty', 'vol-9'), ('okay', 'vol-9'), ('bald', 'vol-9'), ('filthy', 'vol-9'), ('wrong', 'vol-9'), ('many', 'vol-9'), ('more', 'vol-9'), ('smelly', 'vol-9'), ('kindred', 'vol-9'), ('golden', 'vol-9'), ('surprised', 'vol-9'), ('terrible', 'vol-9'), ('elementary', 'vol-9'), ('light', 'vol-9'), ('pleased', 'vol-9'), ('much', 'vol-9'), ('old', 'vol-9'), ('awfull', 'vol-9'), ('famous', 'vol-9'), ('full', 'vol-9'), ('long', 'vol-9'), ('embarrassed', 'vol-9'), ('medium', 'vol-9'), ('third', 'vol-9'), ('next', 'vol-9'), ('inside', 'vol-9'), ('complete', 'vol-9'), ('true', 'vol-9'), ('flintlock', 'vol-9'), ('good', 'vol-9'), ('heavy', 'vol-9'), ('flustered', 'vol-9'), ('angry', 'vol-9'), ('refined', 'vol-9'), ('whole', 'vol-9'), ('great', 'vol-9'), ('right', 'vol-9'), ('popular', 'vol-9'), ('left', 'vol-9')}
# {('long', 'vol-8'), ('same', 'vol-8'), ('rainy', 'vol-8'), ('sunny', 'vol-8'), ('enough', 'vol-8'), ('3rd', 'vol-8'), ('strong', 'vol-8'), ('giant', 'vol-8'), ('non', 'vol-8'), ('short', 'vol-8'), ('stupid', 'vol-8'), ('natural', 'vol-8'), ('artificial', 'vol-8'), ('good', 'vol-8'), ('entire', 'vol-8'), ('easy', 'vol-8'), ('careful', 'vol-8'), ('worth', 'vol-8'), ('impossible', 'vol-8'), ('great', 'vol-8'), ('half', 'vol-8'), ('somethign', 'vol-8'), ('right', 'vol-8'), ('wooden', 'vol-8'), ('left', 'vol-8'), ('cheap', 'vol-8'), ('alien', 'vol-8'), ('other', 'vol-8'), ('low', 'vol-8'), ('bad', 'vol-8'), ('astronomical', 'vol-8'), ('serious', 'vol-8'), ('-', 'vol-8'), ('cool', 'vol-8'), ('high', 'vol-8'), ('astonishing', 'vol-8'), ('many', 'vol-8'), ('amazing', 'vol-8'), ('earthling', 'vol-8'), ('ridiculous', 'vol-8'), ('last', 'vol-8'), ('153rd', 'vol-8'), ('waterproof', 'vol-8'), ('existent', 'vol-8'), ('curious', 'vol-8'), ('notorious', 'vol-8'), ('much', 'vol-8'), ('fat', 'vol-8'), ('courageous', 'vol-8'), ('snowy', 'vol-8'), ('like', 'vol-8'), ('first', 'vol-8')}
# {('trivial', 'vol-16'), ('same', 'vol-16'), ('delicious', 'vol-16'), ('next', 'vol-16'), ('webbed', 'vol-16'), ('good', 'vol-16'), ('own', 'vol-16'), ('shocked', 'vol-16'), ('easy', 'vol-16'), ('big', 'vol-16'), ('only', 'vol-16'), ('right', 'vol-16'), ('happy', 'vol-16'), ('popular', 'vol-16'), ('huge', 'vol-16'), ('normal', 'vol-16'), ('nice', 'vol-16'), ('little', 'vol-16'), ('many', 'vol-16'), ('horrendous', 'vol-16'), ('more', 'vol-16'), ('amazing', 'vol-16'), ('ready', 'vol-16'), ('deep', 'vol-16'), ('super', 'vol-16'), ('awesome', 'vol-16'), ('convenient', 'vol-16'), ('twisty', 'vol-16'), ('sick', 'vol-16'), ('such', 'vol-16'), ('eld', 'vol-16'), ('quick', 'vol-16')}
# {('nice', 'vol-17'), ('-', 'vol-17'), ('mammalian', 'vol-17'), ('beautiful', 'vol-17'), ('original', 'vol-17'), ('official', 'vol-17'), ('awful', 'vol-17'), ('extra', 'vol-17'), ('able', 'vol-17'), ('random', 'vol-17'), ('correct', 'vol-17'), ('first', 'vol-17'), ('full', 'vol-17'), ('same', 'vol-17'), ('giant', 'vol-17'), ('wonderful', 'vol-17'), ('non', 'vol-17'), ('good', 'vol-17'), ('entire', 'vol-17'), ('unnecessary', 'vol-17'), ('precise', 'vol-17'), ('ancient', 'vol-17'), ('difficult', 'vol-17'), ('right', 'vol-17'), ('happy', 'vol-17'), ('sure', 'vol-17'), ('horned', 'vol-17'), ('swedish', 'vol-17')}
# {('important', 'vol-15'), ('olden', 'vol-15'), ('tough', 'vol-15'), ('much', 'vol-15'), ('exciting', 'vol-15'), ('canadian', 'vol-15'), ('future', 'vol-15'), ('wonderful', 'vol-15'), ('knowledgeable', 'vol-15'), ('next', 'vol-15'), ('own', 'vol-15'), ('live', 'vol-15'), ('stupid', 'vol-15'), ('true', 'vol-15'), ('secondhand', 'vol-15'), ('big', 'vol-15'), ('good', 'vol-15'), ('least', 'vol-15'), ('chure', 'vol-15'), ('100th', 'vol-15'), ('right', 'vol-15'), ('other', 'vol-15'), ('further', 'vol-15'), ('young', 'vol-15'), ('nice', 'vol-15'), ('bad', 'vol-15'), ('cool', 'vol-15'), ('serious', 'vol-15'), ('wrong', 'vol-15'), ('portuguese', 'vol-15'), ('pathetic', 'vol-15'), ('more', 'vol-15'), ('grand', 'vol-15'), ('amazing', 'vol-15'), ('stupi', 'vol-15'), ('deep', 'vol-15'), ('real', 'vol-15'), ('such', 'vol-15'), ('terrible', 'vol-15'), ('middle', 'vol-15')}
# {('henohenou_chi', 'vol-14'), ('odd', 'vol-14'), ('good', 'vol-14'), ('raw', 'vol-14'), ('ahem', 'vol-14'), ('easy', 'vol-14'), ('ancient', 'vol-14'), ('legged', 'vol-14'), ('refined', 'vol-14'), ('great', 'vol-14'), ('esp', 'vol-14'), ('mean', 'vol-14'), ('right', 'vol-14'), ('popular', 'vol-14'), ('interested', 'vol-14'), ('miraculous', 'vol-14'), ('italian', 'vol-14'), ('-', 'vol-14'), ('high', 'vol-14'), ('hey', 'vol-14'), ('usoooooopp', 'vol-14'), ('many', 'vol-14'), ('cute', 'vol-14'), ('exact', 'vol-14'), ('expensive', 'vol-14'), ('sweet', 'vol-14'), ('comic', 'vol-14'), ('tyrannical', 'vol-14'), ('egyptian', 'vol-14'), ('curious', 'vol-14'), ('eld', 'vol-14'), ('old', 'vol-14'), ('excited', 'vol-14'), ('cross', 'vol-14'), ('maaa', 'vol-14'), ('striped', 'vol-14'), ('vulgar', 'vol-14'), ('first', 'vol-14'), ('4th', 'vol-14'), ('same', 'vol-14'), ('new', 'vol-14'), ('drunk', 'vol-14'), ('everyday', 'vol-14'), ('own', 'vol-14')}
# {('upper', 'vol-10'), ('terrible', 'vol-10'), ('cut', 'vol-10'), ('sixth', 'vol-10'), ('gigantic', 'vol-10'), ('old', 'vol-10'), ('certain', 'vol-10'), ('first', 'vol-10'), ('full', 'vol-10'), ('crazy', 'vol-10'), ('ridiculous', 'vol-10'), ('short', 'vol-10'), ('bzzzt', 'vol-10'), ('new', 'vol-10'), ('strong', 'vol-10'), ('tall', 'vol-10'), ('wonderful', 'vol-10'), ('good', 'vol-10'), ('careful', 'vol-10'), ('big', 'vol-10'), ('main', 'vol-10'), ('great', 'vol-10'), ('whole', 'vol-10'), ('pointless', 'vol-10'), ('glad', 'vol-10'), ('right', 'vol-10'), ('other', 'vol-10'), ('sudden', 'vol-10'), ('final', 'vol-10'), ('unyielding', 'vol-10'), ('dreadful', 'vol-10'), ('funny', 'vol-10'), ('fine', 'vol-10'), ('little', 'vol-10'), ('nice', 'vol-10'), ('bottom', 'vol-10'), ('small', 'vol-10'), ('decorative', 'vol-10'), ('favorite', 'vol-10'), ('straight', 'vol-10'), ('cute', 'vol-10'), ('many', 'vol-10'), ('chinese', 'vol-10'), ('more', 'vol-10'), ('real', 'vol-10'), ('deep', 'vol-10')}
# {('frequent', 'vol-11'), ('entire', 'vol-11')}
# {('impressive', 'vol-13'), ('curious', 'vol-13'), ('certain', 'vol-13'), ('naked', 'vol-13'), ('first', 'vol-13'), ('close', 'vol-13'), ('short', 'vol-13'), ('new', 'vol-13'), ('likely', 'vol-13'), ('good', 'vol-13'), ('confusing', 'vol-13'), ('excellent', 'vol-13'), ('great', 'vol-13'), ('outward', 'vol-13'), ('happy', 'vol-13'), ('sighted', 'vol-13'), ('normal', 'vol-13'), ('graphic', 'vol-13'), ('bottom', 'vol-13'), ('small', 'vol-13'), ('nice', 'vol-13'), ('little', 'vol-13'), ('cool', 'vol-13'), ('straight', 'vol-13'), ('white', 'vol-13'), ('blurry', 'vol-13'), ('ready', 'vol-13'), ('worthy', 'vol-13')}
# {('la', 'vol-12'), ('lucky', 'vol-12'), ('ready', 'vol-12'), ('hot', 'vol-12'), ('41st', 'vol-12'), ('curious', 'vol-12'), ('old', 'vol-12'), ('unauthorized', 'vol-12'), ('complicated', 'vol-12'), ('cold', 'vol-12'), ('part', 'vol-12'), ('famous', 'vol-12'), ('first', 'vol-12'), ('sexy', 'vol-12'), ('embarrassed', 'vol-12'), ('same', 'vol-12'), ('several', 'vol-12'), ('strong', 'vol-12'), ('uhhh', 'vol-12'), ('next', 'vol-12'), ('splendid', 'vol-12'), ('facial', 'vol-12'), ('webbed', 'vol-12'), ('easy', 'vol-12'), ('hard', 'vol-12'), ('previous', 'vol-12'), ('whole', 'vol-12'), ('right', 'vol-12'), ('happy', 'vol-12'), ('specific', 'vol-12'), ('sure', 'vol-12'), ('sudden', 'vol-12'), ('interested', 'vol-12'), ('sorry', 'vol-12'), ('little', 'vol-12'), ('cool', 'vol-12'), ('ooh', 'vol-12'), ('straight', 'vol-12'), ('okay', 'vol-12'), ('high', 'vol-12'), ('wrong', 'vol-12'), ('local', 'vol-12')}
# {('least', 'vol-23'), ('proper', 'vol-23'), ('main', 'vol-23'), ('great', 'vol-23'), ('5th', 'vol-23'), ('worldly', 'vol-23'), ('changed', 'vol-23'), ('happy', 'vol-23'), ('other', 'vol-23'), ('left', 'vol-23'), ('sure', 'vol-23'), ('interested', 'vol-23'), ('6th', 'vol-23'), ('free', 'vol-23'), ('sorry', 'vol-23'), ('bad', 'vol-23'), ('funny', 'vol-23'), ('little', 'vol-23'), ('fair', 'vol-23'), ('bottom', 'vol-23'), ('cool', 'vol-23'), ('esoteric', 'vol-23'), ('wrong', 'vol-23'), ('different', 'vol-23'), ('dedicated', 'vol-23'), ('upper', 'vol-23'), ('7th', 'vol-23'), ('humorous', 'vol-23'), ('surprised', 'vol-23'), ('strange', 'vol-23'), ('deep', 'vol-23'), ('such', 'vol-23'), ('ish', 'vol-23'), ('best', 'vol-23'), ('afraid', 'vol-23'), ('foreign', 'vol-23'), ('middle', 'vol-23'), ('exciting', 'vol-23'), ('quick', 'vol-23'), ('first', 'vol-23'), ('duper', 'vol-23'), ('like', 'vol-23'), ('sexy', 'vol-23'), ('3rd', 'vol-23'), ('4th', 'vol-23'), ('same', 'vol-23'), ('professional', 'vol-23'), ('2nd', 'vol-23'), ('western', 'vol-23'), ('next', 'vol-23'), ('ahem', 'vol-23')}
# {('widespread', 'vol-22'), ('other', 'vol-22'), ('green', 'vol-22'), ('fine', 'vol-22'), ('bad', 'vol-22'), ('japanese', 'vol-22'), ('high', 'vol-22'), ('chinese', 'vol-22'), ('more', 'vol-22'), ('weird', 'vol-22'), ('unique', 'vol-22'), ('suigun', 'vol-22'), ('direct', 'vol-22'), ('famous', 'vol-22'), ('long', 'vol-22'), ('short', 'vol-22'), ('next', 'vol-22'), ('big', 'vol-22'), ('good', 'vol-22'), ('basic', 'vol-22'), ('mysterious', 'vol-22'), ('expeditionary', 'vol-22'), ('korean', 'vol-22')}
# {('okay', 'vol-20'), ('wrong', 'vol-20'), ('many', 'vol-20'), ('simple', 'vol-20'), ('dear', 'vol-20'), ('chinese', 'vol-20'), ('top', 'vol-20'), ('more', 'vol-20'), ('editorial', 'vol-20'), ('dirty', 'vol-20'), ('witted', 'vol-20'), ('relentless', 'vol-20'), ('real', 'vol-20'), ('enthusiastic', 'vol-20'), ('awful', 'vol-20'), ('scary', 'vol-20'), ('ostentatious', 'vol-20'), ('middle', 'vol-20'), ('cute', 'vol-20'), ('old', 'vol-20'), ('former', 'vol-20'), ('tootin', 'vol-20'), ('certain', 'vol-20'), ('prevalent', 'vol-20'), ('secret', 'vol-20'), ('like', 'vol-20'), ('impressed', 'vol-20'), ('tall', 'vol-20'), ('picky', 'vol-20'), ('next', 'vol-20'), ('own', 'vol-20'), ('sacred', 'vol-20'), ('true', 'vol-20'), ('hard', 'vol-20'), ('good', 'vol-20'), ('great', 'vol-20'), ('only', 'vol-20'), ('refined', 'vol-20'), ('baroque', 'vol-20'), ('difficult', 'vol-20'), ('right', 'vol-20'), ('extravagant', 'vol-20'), ('human', 'vol-20'), ('huge', 'vol-20'), ('17th', 'vol-20'), ('other', 'vol-20'), ('dang', 'vol-20'), ('young', 'vol-20'), ('normal', 'vol-20'), ('nice', 'vol-20'), ('serious', 'vol-20'), ('little', 'vol-20'), ('female', 'vol-20'), ('tense', 'vol-20')}
# {('lonely', 'vol-21'), ('correct', 'vol-21'), ('much', 'vol-21'), ('former', 'vol-21'), ('boring', 'vol-21'), ('first', 'vol-21'), ('full', 'vol-21'), ('close', 'vol-21'), ('current', 'vol-21'), ('same', 'vol-21'), ('strong', 'vol-21'), ('next', 'vol-21'), ('uhhh', 'vol-21'), ('true', 'vol-21'), ('2nd', 'vol-21'), ('drunk', 'vol-21'), ('good', 'vol-21'), ('uhhhhhh', 'vol-21'), ('easy', 'vol-21'), ('big', 'vol-21'), ('orange', 'vol-21'), ('5th', 'vol-21'), ('sober', 'vol-21'), ('impossible', 'vol-21'), ('mean', 'vol-21'), ('second', 'vol-21'), ('right', 'vol-21'), ('other', 'vol-21'), ('happy', 'vol-21'), ('left', 'vol-21'), ('sure', 'vol-21'), ('green', 'vol-21'), ('little', 'vol-21'), ('most', 'vol-21'), ('different', 'vol-21'), ('large', 'vol-21'), ('more', 'vol-21'), ('surprised', 'vol-21'), ('such', 'vol-21')}
# {('true', 'vol-25'), ('good', 'vol-25'), ('related', 'vol-25'), ('heavy', 'vol-25'), ('proper', 'vol-25'), ('ro', 'vol-25'), ('fast', 'vol-25'), ('big', 'vol-25'), ('right', 'vol-25'), ('fuzzy', 'vol-25'), ('left', 'vol-25'), ('fun', 'vol-25'), ('other', 'vol-25'), ('floaty', 'vol-25'), ('huge', 'vol-25'), ('sudden', 'vol-25'), ('north', 'vol-25'), ('serious', 'vol-25'), ('small', 'vol-25'), ('violent', 'vol-25'), ('massive', 'vol-25'), ('dangerous', 'vol-25'), ('high', 'vol-25'), ('honorific', 'vol-25'), ('single', 'vol-25'), ('many', 'vol-25'), ('more', 'vol-25'), ('sumo', 'vol-25'), ('large', 'vol-25'), ('near', 'vol-25'), ('favourite', 'vol-25'), ('surprised', 'vol-25'), ('middle', 'vol-25'), ('english', 'vol-25'), ('american', 'vol-25'), ('correct', 'vol-25'), ('naked', 'vol-25'), ('long', 'vol-25'), ('same', 'vol-25'), ('late', 'vol-25'), ('next', 'vol-25'), ('merry', 'vol-25')}
# {('enough', 'vol-19'), ('next', 'vol-19'), ('big', 'vol-19'), ('good', 'vol-19'), ('main', 'vol-19'), ('special', 'vol-19'), ('only', 'vol-19'), ('worried', 'vol-19'), ('right', 'vol-19'), ('human', 'vol-19'), ('left', 'vol-19'), ('other', 'vol-19'), ('nice', 'vol-19'), ('bad', 'vol-19'), ('serious', 'vol-19'), ('dangerous', 'vol-19'), ('8th', 'vol-19'), ('well', 'vol-19'), ('high', 'vol-19'), ('many', 'vol-19'), ('surprising', 'vol-19'), ('chinese', 'vol-19'), ('slow', 'vol-19'), ('sayeen', 'vol-19'), ('middle', 'vol-19'), ('fried', 'vol-19'), ('bloody', 'vol-19'), ('old', 'vol-19'), ('possible', 'vol-19'), ('full', 'vol-19'), ('same', 'vol-19')}
# {('right', 'vol-18'), ('happy', 'vol-18'), ('other', 'vol-18'), ('young', 'vol-18'), ('sure', 'vol-18'), ('huge', 'vol-18'), ('bad', 'vol-18'), ('sorry', 'vol-18'), ('small', 'vol-18'), ('serious', 'vol-18'), ('actual', 'vol-18'), ('little', 'vol-18'), ('female', 'vol-18'), ('cool', 'vol-18'), ('japanese', 'vol-18'), ('beloved', 'vol-18'), ('male', 'vol-18'), ('wrong', 'vol-18'), ('different', 'vol-18'), ('incredible', 'vol-18'), ('hilarious', 'vol-18'), ('correct', 'vol-18'), ('certain', 'vol-18'), ('curious', 'vol-18'), ('important', 'vol-18'), ('much', 'vol-18'), ('unapologetic', 'vol-18'), ('cold', 'vol-18'), ('naked', 'vol-18'), ('secret', 'vol-18'), ('embarrassed', 'vol-18'), ('same', 'vol-18'), ('new', 'vol-18'), ('next', 'vol-18'), ('enough', 'vol-18'), ('good', 'vol-18'), ('main', 'vol-18'), ('easy', 'vol-18'), ('open', 'vol-18'), ('entire', 'vol-18'), ('MOST', 'vol-18'), ('special', 'vol-18'), ('embarrassing', 'vol-18'), ('mighty', 'vol-18'), ('difficult', 'vol-18')}
# {('cold', 'vol-24'), ('proud', 'vol-24'), ('4th', 'vol-24'), ('enough', 'vol-24'), ('embarrassed', 'vol-24'), ('2nd', 'vol-24'), ('personal', 'vol-24'), ('next', 'vol-24'), ('own', 'vol-24'), ('big', 'vol-24'), ('basic', 'vol-24'), ('erotic', 'vol-24'), ('angry', 'vol-24'), ('orange', 'vol-24'), ('whole', 'vol-24'), ('jealous', 'vol-24'), ('great', 'vol-24'), ('similar', 'vol-24'), ('right', 'vol-24'), ('other', 'vol-24'), ('17th', 'vol-24'), ('normal', 'vol-24'), ('common', 'vol-24'), ('cool', 'vol-24'), ('small', 'vol-24'), ('red', 'vol-24'), ('serious', 'vol-24'), ('little', 'vol-24'), ('instant', 'vol-24'), ('many', 'vol-24'), ('drawn', 'vol-24'), ('simple', 'vol-24'), ('marine', 'vol-24'), ('more', 'vol-24'), ('weekly', 'vol-24'), ('armed', 'vol-24'), ('ish', 'vol-24'), ('regular', 'vol-24'), ('presumptuous', 'vol-24'), ('royalist', 'vol-24'), ('calm', 'vol-24'), ('extra', 'vol-24'), ('private', 'vol-24'), ('correct', 'vol-24'), ('clever', 'vol-24'), ('major', 'vol-24')}
# {('same', 'vol-26'), ('next', 'vol-26'), ('main', 'vol-26'), ('french', 'vol-26'), ('stupid', 'vol-26'), ('careful', 'vol-26'), ('few', 'vol-26'), ('happy', 'vol-26'), ('other', 'vol-26'), ('fine', 'vol-26'), ('little', 'vol-26'), ('japanese', 'vol-26'), ('international', 'vol-26'), ('different', 'vol-26'), ('interesting', 'vol-26'), ('strange', 'vol-26'), ('surprised', 'vol-26'), ('such', 'vol-26'), ('able', 'vol-26'), ('foreign', 'vol-26'), ('american', 'vol-26'), ('unique', 'vol-26'), ('silly', 'vol-26')}
# {('rude', 'vol-27'), ('good', 'vol-27'), ('french', 'vol-27'), ('sisterly', 'vol-27'), ('natural', 'vol-27'), ('careful', 'vol-27'), ('big', 'vol-27'), ('convinced', 'vol-27'), ('main', 'vol-27'), ('fake', 'vol-27'), ('wide', 'vol-27'), ('stuck', 'vol-27'), ('popular', 'vol-27'), ('right', 'vol-27'), ('other', 'vol-27'), ('left', 'vol-27'), ('young', 'vol-27'), ('sure', 'vol-27'), ('sudden', 'vol-27'), ('bad', 'vol-27'), ('free', 'vol-27'), ('maximum', 'vol-27'), ('funny', 'vol-27'), ('little', 'vol-27'), ('ashamed', 'vol-27'), ('cool', 'vol-27'), ('queenly', 'vol-27'), ('japanese', 'vol-27'), ('well', 'vol-27'), ('wrong', 'vol-27'), ('simple', 'vol-27'), ('traditional', 'vol-27'), ('many', 'vol-27'), ('horrible', 'vol-27'), ('large', 'vol-27'), ('expensive', 'vol-27'), ('amazing', 'vol-27'), ('more', 'vol-27'), ('real', 'vol-27'), ('chinese', 'vol-27'), ('black', 'vol-27'), ('opposite', 'vol-27'), ('such', 'vol-27'), ('random', 'vol-27'), ('important', 'vol-27'), ('careless', 'vol-27'), ('old', 'vol-27'), ('full', 'vol-27'), ('secret', 'vol-27'), ('same', 'vol-27'), ('next', 'vol-27'), ('true', 'vol-27')}
# {('useful', 'vol-6'), ('right', 'vol-6'), ('brown', 'vol-6'), ('other', 'vol-6'), ('key', 'vol-6'), ('relaxing', 'vol-6'), ('interested', 'vol-6'), ('bad', 'vol-6'), ('little', 'vol-6'), ('female', 'vol-6'), ('dangerous', 'vol-6'), ('hungry', 'vol-6'), ('japanese', 'vol-6'), ('cute', 'vol-6'), ('wrong', 'vol-6'), ('many', 'vol-6'), ('more', 'vol-6'), ('weekly', 'vol-6'), ('kindred', 'vol-6'), ('accurate', 'vol-6'), ('armed', 'vol-6'), ('scary', 'vol-6'), ('weirdo', 'vol-6'), ('weird', 'vol-6'), ('able', 'vol-6'), ('various', 'vol-6'), ('old', 'vol-6'), ('striped', 'vol-6'), ('handy', 'vol-6'), ('first', 'vol-6'), ('same', 'vol-6'), ('current', 'vol-6'), ('wonderful', 'vol-6'), ('exact', 'vol-6'), ('new', 'vol-6'), ('personal', 'vol-6'), ('third', 'vol-6'), ('hard', 'vol-6'), ('good', 'vol-6'), ('own', 'vol-6'), ('mysterious', 'vol-6'), ('careful', 'vol-6'), ('disgusting', 'vol-6'), ('special', 'vol-6'), ('odd', 'vol-6'), ('fake', 'vol-6'), ('worth', 'vol-6'), ('second', 'vol-6'), ('occasional', 'vol-6')}
# {('clear', 'vol-7'), ('silly', 'vol-7'), ('mammoth', 'vol-7'), ('first', 'vol-7'), ('double', 'vol-7'), ('short', 'vol-7'), ('wonderful', 'vol-7'), ('same', 'vol-7'), ('circular', 'vol-7'), ('ok', 'vol-7'), ('powerful', 'vol-7'), ('true', 'vol-7'), ('hard', 'vol-7'), ('artistic', 'vol-7'), ('mad', 'vol-7'), ('raw', 'vol-7'), ('technical', 'vol-7'), ('least', 'vol-7'), ('fake', 'vol-7'), ('broken', 'vol-7'), ('great', 'vol-7'), ('tidal', 'vol-7'), ('similar', 'vol-7'), ('right', 'vol-7'), ('cheap', 'vol-7'), ('fun', 'vol-7'), ('strained', 'vol-7'), ('bad', 'vol-7'), ('funky', 'vol-7'), ('funny', 'vol-7'), ('little', 'vol-7'), ('braided', 'vol-7'), ('dumb', 'vol-7'), ('okay', 'vol-7'), ('perfect', 'vol-7'), ('nervous', 'vol-7'), ('tired', 'vol-7'), ('many', 'vol-7'), ('more', 'vol-7'), ('top', 'vol-7'), ('amazing', 'vol-7'), ('upper', 'vol-7'), ('elementary', 'vol-7'), ('spanish', 'vol-7'), ('terrible', 'vol-7'), ('able', 'vol-7'), ('valuable', 'vol-7'), ('certain', 'vol-7'), ('old', 'vol-7')}
# {('careful', 'vol-5'), ('real', 'vol-5'), ('sorry', 'vol-5'), ('black', 'vol-5'), ('damn', 'vol-5'), ('first', 'vol-5'), ('sound', 'vol-5'), ('weird', 'vol-5'), ('partial', 'vol-5'), ('able', 'vol-5'), ('well', 'vol-5'), ('white', 'vol-5'), ('simple', 'vol-5'), ('german', 'vol-5'), ('much', 'vol-5'), ('donnnn', 'vol-5')}
# {('former', 'vol-4'), ('correct', 'vol-4'), ('painful', 'vol-4'), ('much', 'vol-4'), ('old', 'vol-4'), ('alive', 'vol-4'), ('disrespectful', 'vol-4'), ('proud', 'vol-4'), ('long', 'vol-4'), ('same', 'vol-4'), ('Most', 'vol-4'), ('new', 'vol-4'), ('good', 'vol-4'), ('secondary', 'vol-4'), ('stupid', 'vol-4'), ('mysterious', 'vol-4'), ('special', 'vol-4'), ('big', 'vol-4'), ('d', 'vol-4'), ('great', 'vol-4'), ('patient', 'vol-4'), ('other', 'vol-4'), ('young', 'vol-4'), ('normal', 'vol-4'), ('cruel', 'vol-4'), ('little', 'vol-4'), ('honest', 'vol-4'), ('cool', 'vol-4'), ('nervous', 'vol-4'), ('high', 'vol-4'), ('simple', 'vol-4'), ('dead', 'vol-4'), ('interesting', 'vol-4'), ('axe', 'vol-4'), ('many', 'vol-4'), ('expensive', 'vol-4'), ('real', 'vol-4'), ('hilarious', 'vol-4'), ('sharp', 'vol-4'), ('weird', 'vol-4'), ('last', 'vol-4')}

# %% [markdown]
# ### Let's try dataframes to store these relations of word-form to unit
# Dataframes, supporteed by the pandas library in Python, facilitate handling data in spreadsheet / CSV / TSV format.
# We want to output some data to a TSV (tab-separated values file) so we can send it to network visualization software.
#
# We'll need to open a terminal and  **pip install pandas** (or python3.12 -m pip install pandas) to get dataframes working.

# %%
import pandas as pd

def wordCollector(words, unit):
    wordList = []
    nodeAtts = []
    unitList = []
    for token in words:
        if token.pos_ == "ADJ":
            wordList.append(token.lemma_)
            nodeAtts.append(token.pos_)
            unitList.append(unit)

    data = {
        'word': wordList,
        'nodeType': nodeAtts,
        'unit': unitList
    }
    df = pd.DataFrame(data)
    return df

for file in os.listdir(collPath):
    if file.endswith(".txt"):
        filepath = f"{collPath}/{file}"
        name, extension = os.path.splitext(file)
        with open(filepath, 'r', encoding='utf8') as f:
            readFile = f.read()
            spacyRead = nlp(readFile)
            myDataFrame = wordCollector(spacyRead, name)
            print(myDataFrame)
# Out:
#          word nodeType   unit
# 0        okay      ADJ  vol-9
# 1       third      ADJ  vol-9
# 2       small      ADJ  vol-9
# 3   surprised      ADJ  vol-9
# 4      famous      ADJ  vol-9
# ..        ...      ...    ...
# 56        old      ADJ  vol-9
# 57       more      ADJ  vol-9
# 58        bad      ADJ  vol-9
# 59     smelly      ADJ  vol-9
# 60       next      ADJ  vol-9
#
# [61 rows x 3 columns]
#             word nodeType   unit
# 0           same      ADJ  vol-8
# 1           long      ADJ  vol-8
# 2      earthling      ADJ  vol-8
# 3           half      ADJ  vol-8
# 4          alien      ADJ  vol-8
# ..           ...      ...    ...
# 60         other      ADJ  vol-8
# 61  astronomical      ADJ  vol-8
# 62       careful      ADJ  vol-8
# 63     notorious      ADJ  vol-8
# 64    ridiculous      ADJ  vol-8
#
# [65 rows x 3 columns]
#           word nodeType    unit
# 0      popular      ADJ  vol-16
# 1        ready      ADJ  vol-16
# 2         good      ADJ  vol-16
# 3        quick      ADJ  vol-16
# 4        right      ADJ  vol-16
# 5       little      ADJ  vol-16
# 6         same      ADJ  vol-16
# 7         more      ADJ  vol-16
# 8         many      ADJ  vol-16
# 9      shocked      ADJ  vol-16
# 10        only      ADJ  vol-16
# 11         eld      ADJ  vol-16
# 12   delicious      ADJ  vol-16
# 13  horrendous      ADJ  vol-16
# 14       happy      ADJ  vol-16
# 15        sick      ADJ  vol-16
# 16        sick      ADJ  vol-16
# 17      normal      ADJ  vol-16
# 18  convenient      ADJ  vol-16
# 19        easy      ADJ  vol-16
# 20       right      ADJ  vol-16
# 21        such      ADJ  vol-16
# 22     trivial      ADJ  vol-16
# 23       super      ADJ  vol-16
# 24     amazing      ADJ  vol-16
# 25        huge      ADJ  vol-16
# 26      webbed      ADJ  vol-16
# 27     awesome      ADJ  vol-16
# 28        good      ADJ  vol-16
# 29        next      ADJ  vol-16
# 30         big      ADJ  vol-16
# 31      twisty      ADJ  vol-16
# 32     amazing      ADJ  vol-16
# 33         own      ADJ  vol-16
# 34        deep      ADJ  vol-16
# 35        same      ADJ  vol-16
# 36       ready      ADJ  vol-16
# 37        nice      ADJ  vol-16
# 38         own      ADJ  vol-16
# 39        good      ADJ  vol-16
# 40        next      ADJ  vol-16
#            word nodeType    unit
# 0         first      ADJ  vol-17
# 1        random      ADJ  vol-17
# 2          sure      ADJ  vol-17
# 3     difficult      ADJ  vol-17
# 4         awful      ADJ  vol-17
# 5        horned      ADJ  vol-17
# 6       swedish      ADJ  vol-17
# 7         right      ADJ  vol-17
# 8         giant      ADJ  vol-17
# 9      original      ADJ  vol-17
# 10      correct      ADJ  vol-17
# 11      precise      ADJ  vol-17
# 12         same      ADJ  vol-17
# 13        giant      ADJ  vol-17
# 14          non      ADJ  vol-17
# 15            -      ADJ  vol-17
# 16    mammalian      ADJ  vol-17
# 17     official      ADJ  vol-17
# 18         able      ADJ  vol-17
# 19      ancient      ADJ  vol-17
# 20         full      ADJ  vol-17
# 21      ancient      ADJ  vol-17
# 22    beautiful      ADJ  vol-17
# 23    wonderful      ADJ  vol-17
# 24        happy      ADJ  vol-17
# 25        right      ADJ  vol-17
# 26         nice      ADJ  vol-17
# 27      ancient      ADJ  vol-17
# 28         nice      ADJ  vol-17
# 29         good      ADJ  vol-17
# 30         full      ADJ  vol-17
# 31       entire      ADJ  vol-17
# 32        extra      ADJ  vol-17
# 33         nice      ADJ  vol-17
# 34  unnecessary      ADJ  vol-17
# 35         good      ADJ  vol-17
#              word nodeType    unit
# 0      portuguese      ADJ  vol-15
# 1           olden      ADJ  vol-15
# 2   knowledgeable      ADJ  vol-15
# 3       important      ADJ  vol-15
# 4            much      ADJ  vol-15
# 5            deep      ADJ  vol-15
# 6            more      ADJ  vol-15
# 7           100th      ADJ  vol-15
# 8            cool      ADJ  vol-15
# 9            real      ADJ  vol-15
# 10          grand      ADJ  vol-15
# 11          other      ADJ  vol-15
# 12            big      ADJ  vol-15
# 13       exciting      ADJ  vol-15
# 14            bad      ADJ  vol-15
# 15           live      ADJ  vol-15
# 16           good      ADJ  vol-15
# 17           nice      ADJ  vol-15
# 18        further      ADJ  vol-15
# 19           true      ADJ  vol-15
# 20           next      ADJ  vol-15
# 21     secondhand      ADJ  vol-15
# 22           such      ADJ  vol-15
# 23       canadian      ADJ  vol-15
# 24           good      ADJ  vol-15
# 25         middle      ADJ  vol-15
# 26         future      ADJ  vol-15
# 27        serious      ADJ  vol-15
# 28        serious      ADJ  vol-15
# 29          wrong      ADJ  vol-15
# 30          young      ADJ  vol-15
# 31            own      ADJ  vol-15
# 32           much      ADJ  vol-15
# 33          young      ADJ  vol-15
# 34           such      ADJ  vol-15
# 35       terrible      ADJ  vol-15
# 36        amazing      ADJ  vol-15
# 37           such      ADJ  vol-15
# 38      wonderful      ADJ  vol-15
# 39         stupid      ADJ  vol-15
# 40          stupi      ADJ  vol-15
# 41       pathetic      ADJ  vol-15
# 42          least      ADJ  vol-15
# 43       pathetic      ADJ  vol-15
# 44          chure      ADJ  vol-15
# 45          right      ADJ  vol-15
# 46          tough      ADJ  vol-15
# 47           next      ADJ  vol-15
#              word nodeType    unit
# 0             own      ADJ  vol-14
# 1           great      ADJ  vol-14
# 2            good      ADJ  vol-14
# 3         popular      ADJ  vol-14
# 4       expensive      ADJ  vol-14
# 5            high      ADJ  vol-14
# 6           exact      ADJ  vol-14
# 7            same      ADJ  vol-14
# 8        everyday      ADJ  vol-14
# 9           comic      ADJ  vol-14
# 10           same      ADJ  vol-14
# 11           same      ADJ  vol-14
# 12          cross      ADJ  vol-14
# 13              -      ADJ  vol-14
# 14         legged      ADJ  vol-14
# 15           cute      ADJ  vol-14
# 16        curious      ADJ  vol-14
# 17         vulgar      ADJ  vol-14
# 18            4th      ADJ  vol-14
# 19            old      ADJ  vol-14
# 20          drunk      ADJ  vol-14
# 21          drunk      ADJ  vol-14
# 22            eld      ADJ  vol-14
# 23        excited      ADJ  vol-14
# 24        italian      ADJ  vol-14
# 25            raw      ADJ  vol-14
# 26          sweet      ADJ  vol-14
# 27     miraculous      ADJ  vol-14
# 28           many      ADJ  vol-14
# 29            raw      ADJ  vol-14
# 30            raw      ADJ  vol-14
# 31           easy      ADJ  vol-14
# 32  henohenou_chi      ADJ  vol-14
# 33          right      ADJ  vol-14
# 34          right      ADJ  vol-14
# 35     tyrannical      ADJ  vol-14
# 36        refined      ADJ  vol-14
# 37           ahem      ADJ  vol-14
# 38           maaa      ADJ  vol-14
# 39     interested      ADJ  vol-14
# 40           maaa      ADJ  vol-14
# 41          first      ADJ  vol-14
# 42            hey      ADJ  vol-14
# 43     usoooooopp      ADJ  vol-14
# 44            odd      ADJ  vol-14
# 45            new      ADJ  vol-14
# 46            new      ADJ  vol-14
# 47            esp      ADJ  vol-14
# 48            new      ADJ  vol-14
# 49           good      ADJ  vol-14
# 50       egyptian      ADJ  vol-14
# 51        striped      ADJ  vol-14
# 52        ancient      ADJ  vol-14
# 53        striped      ADJ  vol-14
# 54       egyptian      ADJ  vol-14
# 55           mean      ADJ  vol-14
#           word nodeType    unit
# 0        sixth      ADJ  vol-10
# 1        whole      ADJ  vol-10
# 2        small      ADJ  vol-10
# 3       bottom      ADJ  vol-10
# 4        upper      ADJ  vol-10
# 5        other      ADJ  vol-10
# 6        bzzzt      ADJ  vol-10
# 7         cute      ADJ  vol-10
# 8         main      ADJ  vol-10
# 9        short      ADJ  vol-10
# 10         cut      ADJ  vol-10
# 11       funny      ADJ  vol-10
# 12        full      ADJ  vol-10
# 13     chinese      ADJ  vol-10
# 14        fine      ADJ  vol-10
# 15  decorative      ADJ  vol-10
# 16        real      ADJ  vol-10
# 17        deep      ADJ  vol-10
# 18  decorative      ADJ  vol-10
# 19   pointless      ADJ  vol-10
# 20        more      ADJ  vol-10
# 21       first      ADJ  vol-10
# 22    favorite      ADJ  vol-10
# 23      little      ADJ  vol-10
# 24      sudden      ADJ  vol-10
# 25     careful      ADJ  vol-10
# 26       final      ADJ  vol-10
# 27       right      ADJ  vol-10
# 28        tall      ADJ  vol-10
# 29     certain      ADJ  vol-10
# 30  unyielding      ADJ  vol-10
# 31       right      ADJ  vol-10
# 32         new      ADJ  vol-10
# 33        good      ADJ  vol-10
# 34       right      ADJ  vol-10
# 35        good      ADJ  vol-10
# 36        glad      ADJ  vol-10
# 37       crazy      ADJ  vol-10
# 38       crazy      ADJ  vol-10
# 39         old      ADJ  vol-10
# 40         big      ADJ  vol-10
# 41      strong      ADJ  vol-10
# 42    straight      ADJ  vol-10
# 43   wonderful      ADJ  vol-10
# 44    gigantic      ADJ  vol-10
# 45        nice      ADJ  vol-10
# 46      little      ADJ  vol-10
# 47    terrible      ADJ  vol-10
# 48    dreadful      ADJ  vol-10
# 49        many      ADJ  vol-10
# 50       great      ADJ  vol-10
# 51        many      ADJ  vol-10
# 52  ridiculous      ADJ  vol-10
#        word nodeType    unit
# 0  frequent      ADJ  vol-11
# 1    entire      ADJ  vol-11
#           word nodeType    unit
# 0      certain      ADJ  vol-13
# 1        happy      ADJ  vol-13
# 2        great      ADJ  vol-13
# 3        first      ADJ  vol-13
# 4        ready      ADJ  vol-13
# 5       worthy      ADJ  vol-13
# 6       bottom      ADJ  vol-13
# 7        naked      ADJ  vol-13
# 8      sighted      ADJ  vol-13
# 9        short      ADJ  vol-13
# 10     sighted      ADJ  vol-13
# 11       close      ADJ  vol-13
# 12      blurry      ADJ  vol-13
# 13      likely      ADJ  vol-13
# 14        good      ADJ  vol-13
# 15        nice      ADJ  vol-13
# 16     graphic      ADJ  vol-13
# 17       small      ADJ  vol-13
# 18        cool      ADJ  vol-13
# 19  impressive      ADJ  vol-13
# 20     curious      ADJ  vol-13
# 21      little      ADJ  vol-13
# 22     outward      ADJ  vol-13
# 23       white      ADJ  vol-13
# 24    straight      ADJ  vol-13
# 25      normal      ADJ  vol-13
# 26   excellent      ADJ  vol-13
# 27        good      ADJ  vol-13
# 28         new      ADJ  vol-13
# 29       first      ADJ  vol-13
# 30   confusing      ADJ  vol-13
#             word nodeType    unit
# 0         strong      ADJ  vol-12
# 1          right      ADJ  vol-12
# 2          sorry      ADJ  vol-12
# 3           uhhh      ADJ  vol-12
# 4           cool      ADJ  vol-12
# 5           cool      ADJ  vol-12
# 6           easy      ADJ  vol-12
# 7          ready      ADJ  vol-12
# 8           next      ADJ  vol-12
# 9   unauthorized      ADJ  vol-12
# 10          okay      ADJ  vol-12
# 11         happy      ADJ  vol-12
# 12   complicated      ADJ  vol-12
# 13       several      ADJ  vol-12
# 14         right      ADJ  vol-12
# 15          sure      ADJ  vol-12
# 16          hard      ADJ  vol-12
# 17          part      ADJ  vol-12
# 18         lucky      ADJ  vol-12
# 19        facial      ADJ  vol-12
# 20          same      ADJ  vol-12
# 21          same      ADJ  vol-12
# 22          sexy      ADJ  vol-12
# 23           ooh      ADJ  vol-12
# 24            la      ADJ  vol-12
# 25            la      ADJ  vol-12
# 26        famous      ADJ  vol-12
# 27         local      ADJ  vol-12
# 28          sexy      ADJ  vol-12
# 29           hot      ADJ  vol-12
# 30         first      ADJ  vol-12
# 31   embarrassed      ADJ  vol-12
# 32         right      ADJ  vol-12
# 33      specific      ADJ  vol-12
# 34          okay      ADJ  vol-12
# 35      splendid      ADJ  vol-12
# 36          41st      ADJ  vol-12
# 37       curious      ADJ  vol-12
# 38      previous      ADJ  vol-12
# 39        webbed      ADJ  vol-12
# 40         wrong      ADJ  vol-12
# 41          next      ADJ  vol-12
# 42          cold      ADJ  vol-12
# 43        sudden      ADJ  vol-12
# 44        little      ADJ  vol-12
# 45          high      ADJ  vol-12
# 46    interested      ADJ  vol-12
# 47          okay      ADJ  vol-12
# 48      straight      ADJ  vol-12
# 49          okay      ADJ  vol-12
# 50         whole      ADJ  vol-12
# 51         whole      ADJ  vol-12
# 52        little      ADJ  vol-12
# 53           old      ADJ  vol-12
# 54          uhhh      ADJ  vol-12
#         word nodeType    unit
# 0      first      ADJ  vol-23
# 1     afraid      ADJ  vol-23
# 2   humorous      ADJ  vol-23
# 3      least      ADJ  vol-23
# 4       ahem      ADJ  vol-23
# ..       ...      ...     ...
# 60      such      ADJ  vol-23
# 61      deep      ADJ  vol-23
# 62      cool      ADJ  vol-23
# 63      main      ADJ  vol-23
# 64      next      ADJ  vol-23
#
# [65 rows x 3 columns]
#              word nodeType    unit
# 0           weird      ADJ  vol-22
# 1           weird      ADJ  vol-22
# 2            next      ADJ  vol-22
# 3            fine      ADJ  vol-22
# 4            next      ADJ  vol-22
# 5            good      ADJ  vol-22
# 6        japanese      ADJ  vol-22
# 7          direct      ADJ  vol-22
# 8          unique      ADJ  vol-22
# 9        japanese      ADJ  vol-22
# 10           long      ADJ  vol-22
# 11         korean      ADJ  vol-22
# 12        chinese      ADJ  vol-22
# 13  expeditionary      ADJ  vol-22
# 14            bad      ADJ  vol-22
# 15         famous      ADJ  vol-22
# 16            big      ADJ  vol-22
# 17     widespread      ADJ  vol-22
# 18           long      ADJ  vol-22
# 19         suigun      ADJ  vol-22
# 20          short      ADJ  vol-22
# 21           good      ADJ  vol-22
# 22     mysterious      ADJ  vol-22
# 23          other      ADJ  vol-22
# 24           next      ADJ  vol-22
# 25          basic      ADJ  vol-22
# 26           high      ADJ  vol-22
# 27          green      ADJ  vol-22
# 28           more      ADJ  vol-22
#             word nodeType    unit
# 0           good      ADJ  vol-20
# 1         little      ADJ  vol-20
# 2   enthusiastic      ADJ  vol-20
# 3           nice      ADJ  vol-20
# 4           okay      ADJ  vol-20
# ..           ...      ...     ...
# 72          like      ADJ  vol-20
# 73          many      ADJ  vol-20
# 74         great      ADJ  vol-20
# 75          real      ADJ  vol-20
# 76          next      ADJ  vol-20
#
# [77 rows x 3 columns]
#           word nodeType    unit
# 0        right      ADJ  vol-21
# 1       boring      ADJ  vol-21
# 2         good      ADJ  vol-21
# 3         more      ADJ  vol-21
# 4         full      ADJ  vol-21
# 5         left      ADJ  vol-21
# 6        other      ADJ  vol-21
# 7         such      ADJ  vol-21
# 8   impossible      ADJ  vol-21
# 9   impossible      ADJ  vol-21
# 10       close      ADJ  vol-21
# 11       other      ADJ  vol-21
# 12       large      ADJ  vol-21
# 13       other      ADJ  vol-21
# 14        mean      ADJ  vol-21
# 15     uhhhhhh      ADJ  vol-21
# 16        uhhh      ADJ  vol-21
# 17        sure      ADJ  vol-21
# 18       right      ADJ  vol-21
# 19      orange      ADJ  vol-21
# 20        true      ADJ  vol-21
# 21   different      ADJ  vol-21
# 22       green      ADJ  vol-21
# 23   different      ADJ  vol-21
# 24         2nd      ADJ  vol-21
# 25         5th      ADJ  vol-21
# 26        same      ADJ  vol-21
# 27       right      ADJ  vol-21
# 28     correct      ADJ  vol-21
# 29     current      ADJ  vol-21
# 30        easy      ADJ  vol-21
# 31       right      ADJ  vol-21
# 32      little      ADJ  vol-21
# 33        most      ADJ  vol-21
# 34      former      ADJ  vol-21
# 35       first      ADJ  vol-21
# 36       drunk      ADJ  vol-21
# 37   surprised      ADJ  vol-21
# 38      second      ADJ  vol-21
# 39      second      ADJ  vol-21
# 40      strong      ADJ  vol-21
# 41      little      ADJ  vol-21
# 42      lonely      ADJ  vol-21
# 43       happy      ADJ  vol-21
# 44       sober      ADJ  vol-21
# 45   different      ADJ  vol-21
# 46       other      ADJ  vol-21
# 47        next      ADJ  vol-21
# 48         big      ADJ  vol-21
# 49        much      ADJ  vol-21
#          word nodeType    unit
# 0        good      ADJ  vol-25
# 1      sudden      ADJ  vol-25
# 2     related      ADJ  vol-25
# 3        fast      ADJ  vol-25
# 4        good      ADJ  vol-25
# 5          ro      ADJ  vol-25
# 6       naked      ADJ  vol-25
# 7   favourite      ADJ  vol-25
# 8       naked      ADJ  vol-25
# 9     english      ADJ  vol-25
# 10      other      ADJ  vol-25
# 11  honorific      ADJ  vol-25
# 12       good      ADJ  vol-25
# 13     middle      ADJ  vol-25
# 14       next      ADJ  vol-25
# 15       long      ADJ  vol-25
# 16      right      ADJ  vol-25
# 17       left      ADJ  vol-25
# 18     middle      ADJ  vol-25
# 19       many      ADJ  vol-25
# 20     proper      ADJ  vol-25
# 21     floaty      ADJ  vol-25
# 22       sumo      ADJ  vol-25
# 23       good      ADJ  vol-25
# 24       high      ADJ  vol-25
# 25      north      ADJ  vol-25
# 26   american      ADJ  vol-25
# 27    correct      ADJ  vol-25
# 28        big      ADJ  vol-25
# 29       more      ADJ  vol-25
# 30      right      ADJ  vol-25
# 31       left      ADJ  vol-25
# 32      heavy      ADJ  vol-25
# 33      right      ADJ  vol-25
# 34       left      ADJ  vol-25
# 35      right      ADJ  vol-25
# 36       left      ADJ  vol-25
# 37     single      ADJ  vol-25
# 38       true      ADJ  vol-25
# 39    massive      ADJ  vol-25
# 40    serious      ADJ  vol-25
# 41       same      ADJ  vol-25
# 42      merry      ADJ  vol-25
# 43      merry      ADJ  vol-25
# 44    violent      ADJ  vol-25
# 45  dangerous      ADJ  vol-25
# 46       near      ADJ  vol-25
# 47      large      ADJ  vol-25
# 48      small      ADJ  vol-25
# 49        fun      ADJ  vol-25
# 50  surprised      ADJ  vol-25
# 51       late      ADJ  vol-25
# 52       huge      ADJ  vol-25
# 53      fuzzy      ADJ  vol-25
# 54      fuzzy      ADJ  vol-25
# 55       next      ADJ  vol-25
#           word nodeType    unit
# 0     possible      ADJ  vol-19
# 1         main      ADJ  vol-19
# 2         left      ADJ  vol-19
# 3       enough      ADJ  vol-19
# 4          old      ADJ  vol-19
# 5         same      ADJ  vol-19
# 6        human      ADJ  vol-19
# 7        right      ADJ  vol-19
# 8        fried      ADJ  vol-19
# 9      chinese      ADJ  vol-19
# 10         old      ADJ  vol-19
# 11        good      ADJ  vol-19
# 12         old      ADJ  vol-19
# 13        slow      ADJ  vol-19
# 14         old      ADJ  vol-19
# 15       human      ADJ  vol-19
# 16         old      ADJ  vol-19
# 17         bad      ADJ  vol-19
# 18        nice      ADJ  vol-19
# 19        next      ADJ  vol-19
# 20        same      ADJ  vol-19
# 21        many      ADJ  vol-19
# 22        same      ADJ  vol-19
# 23        well      ADJ  vol-19
# 24      middle      ADJ  vol-19
# 25        high      ADJ  vol-19
# 26         8th      ADJ  vol-19
# 27     worried      ADJ  vol-19
# 28       other      ADJ  vol-19
# 29     serious      ADJ  vol-19
# 30     serious      ADJ  vol-19
# 31     special      ADJ  vol-19
# 32   dangerous      ADJ  vol-19
# 33        next      ADJ  vol-19
# 34      bloody      ADJ  vol-19
# 35  surprising      ADJ  vol-19
# 36        same      ADJ  vol-19
# 37       right      ADJ  vol-19
# 38        full      ADJ  vol-19
# 39         big      ADJ  vol-19
# 40      sayeen      ADJ  vol-19
# 41       right      ADJ  vol-19
# 42        only      ADJ  vol-19
# 43       right      ADJ  vol-19
# 44        next      ADJ  vol-19
#            word nodeType    unit
# 0          sure      ADJ  vol-18
# 1     difficult      ADJ  vol-18
# 2          open      ADJ  vol-18
# 3   embarrassed      ADJ  vol-18
# 4        entire      ADJ  vol-18
# ..          ...      ...     ...
# 61         easy      ADJ  vol-18
# 62        happy      ADJ  vol-18
# 63          new      ADJ  vol-18
# 64         next      ADJ  vol-18
# 65       mighty      ADJ  vol-18
#
# [66 rows x 3 columns]
#             word nodeType    unit
# 0           many      ADJ  vol-24
# 1            4th      ADJ  vol-24
# 2         normal      ADJ  vol-24
# 3        regular      ADJ  vol-24
# 4       personal      ADJ  vol-24
# 5         little      ADJ  vol-24
# 6         little      ADJ  vol-24
# 7          basic      ADJ  vol-24
# 8         marine      ADJ  vol-24
# 9          proud      ADJ  vol-24
# 10       private      ADJ  vol-24
# 11         other      ADJ  vol-24
# 12           own      ADJ  vol-24
# 13      personal      ADJ  vol-24
# 14        common      ADJ  vol-24
# 15          more      ADJ  vol-24
# 16        weekly      ADJ  vol-24
# 17          more      ADJ  vol-24
# 18          17th      ADJ  vol-24
# 19       jealous      ADJ  vol-24
# 20           2nd      ADJ  vol-24
# 21         right      ADJ  vol-24
# 22       similar      ADJ  vol-24
# 23        clever      ADJ  vol-24
# 24          cool      ADJ  vol-24
# 25          calm      ADJ  vol-24
# 26           red      ADJ  vol-24
# 27      royalist      ADJ  vol-24
# 28         angry      ADJ  vol-24
# 29         extra      ADJ  vol-24
# 30       correct      ADJ  vol-24
# 31        simple      ADJ  vol-24
# 32         other      ADJ  vol-24
# 33         small      ADJ  vol-24
# 34         armed      ADJ  vol-24
# 35       serious      ADJ  vol-24
# 36         major      ADJ  vol-24
# 37        orange      ADJ  vol-24
# 38           ish      ADJ  vol-24
# 39        orange      ADJ  vol-24
# 40       instant      ADJ  vol-24
# 41       instant      ADJ  vol-24
# 42         whole      ADJ  vol-24
# 43        enough      ADJ  vol-24
# 44         great      ADJ  vol-24
# 45        orange      ADJ  vol-24
# 46           big      ADJ  vol-24
# 47          cold      ADJ  vol-24
# 48        erotic      ADJ  vol-24
# 49   embarrassed      ADJ  vol-24
# 50           big      ADJ  vol-24
# 51         drawn      ADJ  vol-24
# 52  presumptuous      ADJ  vol-24
# 53          next      ADJ  vol-24
#              word nodeType    unit
# 0             few      ADJ  vol-26
# 1         foreign      ADJ  vol-26
# 2   international      ADJ  vol-26
# 3            able      ADJ  vol-26
# 4         foreign      ADJ  vol-26
# 5            main      ADJ  vol-26
# 6         foreign      ADJ  vol-26
# 7     interesting      ADJ  vol-26
# 8         strange      ADJ  vol-26
# 9       different      ADJ  vol-26
# 10      different      ADJ  vol-26
# 11           same      ADJ  vol-26
# 12         unique      ADJ  vol-26
# 13       japanese      ADJ  vol-26
# 14        foreign      ADJ  vol-26
# 15          happy      ADJ  vol-26
# 16         french      ADJ  vol-26
# 17           same      ADJ  vol-26
# 18         french      ADJ  vol-26
# 19        careful      ADJ  vol-26
# 20      surprised      ADJ  vol-26
# 21           such      ADJ  vol-26
# 22           fine      ADJ  vol-26
# 23         little      ADJ  vol-26
# 24          silly      ADJ  vol-26
# 25       american      ADJ  vol-26
# 26       american      ADJ  vol-26
# 27          other      ADJ  vol-26
# 28       japanese      ADJ  vol-26
# 29           same      ADJ  vol-26
# 30           next      ADJ  vol-26
# 31         stupid      ADJ  vol-26
# 32           next      ADJ  vol-26
#         word nodeType    unit
# 0        bad      ADJ  vol-27
# 1   horrible      ADJ  vol-27
# 2    amazing      ADJ  vol-27
# 3    maximum      ADJ  vol-27
# 4       well      ADJ  vol-27
# ..       ...      ...     ...
# 64    sudden      ADJ  vol-27
# 65      main      ADJ  vol-27
# 66      many      ADJ  vol-27
# 67     black      ADJ  vol-27
# 68      next      ADJ  vol-27
#
# [69 rows x 3 columns]
#           word nodeType   unit
# 0         good      ADJ  vol-6
# 1         hard      ADJ  vol-6
# 2     relaxing      ADJ  vol-6
# 3      careful      ADJ  vol-6
# 4      striped      ADJ  vol-6
# 5         good      ADJ  vol-6
# 6      striped      ADJ  vol-6
# 7       hungry      ADJ  vol-6
# 8   disgusting      ADJ  vol-6
# 9         able      ADJ  vol-6
# 10     striped      ADJ  vol-6
# 11       right      ADJ  vol-6
# 12        cute      ADJ  vol-6
# 13      weirdo      ADJ  vol-6
# 14       weird      ADJ  vol-6
# 15       weird      ADJ  vol-6
# 16       weird      ADJ  vol-6
# 17     special      ADJ  vol-6
# 18     special      ADJ  vol-6
# 19         new      ADJ  vol-6
# 20       exact      ADJ  vol-6
# 21     current      ADJ  vol-6
# 22      weekly      ADJ  vol-6
# 23        same      ADJ  vol-6
# 24     various      ADJ  vol-6
# 25         key      ADJ  vol-6
# 26       brown      ADJ  vol-6
# 27        many      ADJ  vol-6
# 28   wonderful      ADJ  vol-6
# 29    japanese      ADJ  vol-6
# 30       first      ADJ  vol-6
# 31    personal      ADJ  vol-6
# 32   dangerous      ADJ  vol-6
# 33  mysterious      ADJ  vol-6
# 34       third      ADJ  vol-6
# 35         odd      ADJ  vol-6
# 36  interested      ADJ  vol-6
# 37       scary      ADJ  vol-6
# 38       other      ADJ  vol-6
# 39      useful      ADJ  vol-6
# 40       handy      ADJ  vol-6
# 41    accurate      ADJ  vol-6
# 42       weird      ADJ  vol-6
# 43       wrong      ADJ  vol-6
# 44         bad      ADJ  vol-6
# 45        many      ADJ  vol-6
# 46      female      ADJ  vol-6
# 47         old      ADJ  vol-6
# 48      second      ADJ  vol-6
# 49       first      ADJ  vol-6
# 50        more      ADJ  vol-6
# 51         own      ADJ  vol-6
# 52       worth      ADJ  vol-6
# 53  occasional      ADJ  vol-6
# 54      little      ADJ  vol-6
# 55        fake      ADJ  vol-6
# 56        same      ADJ  vol-6
# 57       armed      ADJ  vol-6
# 58     kindred      ADJ  vol-6
#         word nodeType   unit
# 0     little      ADJ  vol-7
# 1    perfect      ADJ  vol-7
# 2      funny      ADJ  vol-7
# 3        bad      ADJ  vol-7
# 4        bad      ADJ  vol-7
# ..       ...      ...    ...
# 61  valuable      ADJ  vol-7
# 62    little      ADJ  vol-7
# 63    little      ADJ  vol-7
# 64      dumb      ADJ  vol-7
# 65   similar      ADJ  vol-7
#
# [66 rows x 3 columns]
#        word nodeType   unit
# 0   careful      ADJ  vol-5
# 1     first      ADJ  vol-5
# 2      real      ADJ  vol-5
# 3     sound      ADJ  vol-5
# 4    donnnn      ADJ  vol-5
# 5      damn      ADJ  vol-5
# 6     weird      ADJ  vol-5
# 7     sorry      ADJ  vol-5
# 8    simple      ADJ  vol-5
# 9    german      ADJ  vol-5
# 10     able      ADJ  vol-5
# 11     much      ADJ  vol-5
# 12  partial      ADJ  vol-5
# 13     well      ADJ  vol-5
# 14    black      ADJ  vol-5
# 15    white      ADJ  vol-5
#        word nodeType   unit
# 0       old      ADJ  vol-4
# 1       old      ADJ  vol-4
# 2       old      ADJ  vol-4
# 3       old      ADJ  vol-4
# 4       old      ADJ  vol-4
# ..      ...      ...    ...
# 58     many      ADJ  vol-4
# 59     many      ADJ  vol-4
# 60     many      ADJ  vol-4
# 61     many      ADJ  vol-4
# 62  special      ADJ  vol-4
#
# [63 rows x 3 columns]

# %% [markdown]
# ## Write the dataframes to an output TSV file
# TSV means **tab-separated-values**. We'll use the tab character as a separator.
# The other popular alternative is the CSV: **comma-separated-values**, which uses the comma as a separator.
# You can use either one for our network data.
#
# I'm going to output some "node attributes" for tne network. In a network visualization, we'll want to be able to quickly distinguish the word nodes from the unit nodes (possibly by shape), and providing a qualifier or "node attribute" in the dataframe will be helpful.
# We can add other kinds of node attributes perhaps as numerical ranges (see below).

# %%
import pandas as pd

def wordCollector(words, unit):
    wordList = []
    nodeAtts = []
    unitList = []
    for token in words:
        if token.pos_ == "ADJ":
            wordList.append(token.lemma_)
            nodeAtts.append(token.pos_)
            unitList.append(unit)

    data = {
        'word': wordList,
        'nodeType': nodeAtts,
        'unit': unitList
    }
    df = pd.DataFrame(data)
    return df
    # This is returning a separate dataframe for every source text file. 

# We need to consolidate all the dataframes into one file. Collect all dataframes here!
allDataFrames = []

for file in os.listdir(collPath):
    if file.endswith(".txt"):
        filepath = f"{collPath}/{file}"
        name, extension = os.path.splitext(file)
        with open(filepath, 'r', encoding='utf8') as f:
            readFile = f.read()
            spacyRead = nlp(readFile)
            myDataFrame = wordCollector(spacyRead, name)
            # Add each individual dataframe as it comes out into the list of dataframes!
            allDataFrames.append(myDataFrame)

# Make an output filepath
outputFilePath = 'networkData.tsv'
# Turn the list of dataframes into one dataframe:
fullDataFrame = pd.concat(allDataFrames, ignore_index=True)
# print(fullDataFrame)

# Note, since Pandas knows how to open and write files line by line, we can skip that open() step we used last time.
fullDataFrame.to_csv(outputFilePath, sep='\t', index=False)
print('I just saved a dataframe as a TSV file.')
# Go check your filestash for the file.

# %% [markdown]
# ### Something to try...
# * Try developing this to return synsets from WordNet.
# * Add an Ambiguity metric to count the number of synsets it belongs to.
# * Output this as a second "node attribute" qualifier to the Part of Speech. We could use that to color-code the words by ambiguity...

# %%
# This time, with Wordnet data!
import pandas as pd
import nltk
from nltk.corpus import wordnet as wn

def wordCollector(words, unit):
    wordList = []
    nodeAtts = []
    synsetCounts = []
    unitList = []
    for token in words:
        if token.pos_ == "ADJ":
            synsets = len(wn.synsets(token.lemma_))
            # We should be able to look up and count those synsets right here!          
            wordList.append(token.lemma_)
            nodeAtts.append(token.pos_)
            synsetCounts.append(synsets)
            unitList.append(unit)
                          
    data = {
        'word': wordList,
        'nodeType': nodeAtts,
        'synsetCount': synsetCounts,
        'unit': unitList
    }
    df = pd.DataFrame(data)
    return df
    # This is returning a separate dataframe for every source text file. 

# We need to consolidate all the dataframes into one file. Collect all dataframes here!
allDataFrames = []

for file in os.listdir(collPath):
    if file.endswith(".txt"):
        filepath = f"{collPath}/{file}"
        name, extension = os.path.splitext(file)
        with open(filepath, 'r', encoding='utf8') as f:
            readFile = f.read()
            spacyRead = nlp(readFile)
            myDataFrame = wordCollector(spacyRead, name)
            # Add each individual dataframe as it comes out into the list of dataframes!
            allDataFrames.append(myDataFrame)

# Make an output filepath
outputFilePath = 'networkData-2.tsv'
# Turn the list of dataframes into one dataframe:
fullDataFrame = pd.concat(allDataFrames, ignore_index=True)

# Note, since Pandas knows how to open and write files line by line, we can skip that open() step we used last time.
fullDataFrame.to_csv(outputFilePath, sep='\t', index=False)
print('I just saved a NEW dataframe as a NEW TSV file.')
# Go check your filestash for the file.

# %% [markdown]
# ## What will we do with this fancy TSV?
#
# We can analyze it as a **network** of data using network analysis. You could try importing your TSV into kumu.io, but we're going to introduce Cytoscape, which is a very powerful, artful method with lots of visualization options.
#
# To view the data we extracted in this notebook as an SVG export from Cytoscape, see <https://raw.githubusercontent.com/newtfire/textAnalysis-Hub/refs/heads/main/Class-Examples/Python/readFileCollections-examples/networkData-2.svg>

# %% [markdown]
# ## Your Turn!
# Adapt this notebook to explore one or more of your project files and prepare some network data of your own.
#
# * Output a CSV or TSV of data from your project for import into our network visualization software.
# * [Install Cytoscape](https://cytoscape.org/) on your computer and check to make sure it is working.
#      * Cytoscape now comes bundled with its own Java, so you should be good to go for running it (much like oXygen). If you have trouble, work through the [Troubleshooting](https://cytoscape.org/troubleshooting.html) guide first. Bring questions to class or via Canvas!
#      * After you install Cytoscape, see if you can also install the yFiles Layout Algorithms. Open Cytoscape, go to **Layout → Install yFiles**, which directs you to an App store to download it and apply it to Cytoscape.
